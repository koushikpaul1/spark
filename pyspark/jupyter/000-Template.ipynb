# %%
import findspark
findspark.init()
import pyspark


from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
df = spark.sql("select 'spark' as hello ")
df.show()

# %%
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
spark.conf.set("spark.sql.shuffle.partitions", "5")
print("SparkSession created with name as 'spark'")

# %%
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("001")\
.master("local").config("spark.sql.warehouse.dir", "file:///C:/tmp/hive")\
.getOrCreate()
spark.conf.set("spark.sql.shuffle.partitions", "5")
print("SparkSession created with name as 'spark'")

# %%
df=spark.read.format("csv")\
.option("header", "true")\
.option("inferSchema", "true")\
.load("../../data/SparkTheDefinitiveGuide/retail-data/by-day/2010-12-01.csv")
df.printSchema()
df.createOrReplaceTempView("dfTable")

# %%
df=spark.read.format("csv")\
.option("header", "true")\
.option("inferSchema", "true")\
.load("../../data/SparkTheDefinitiveGuide/retail-data/by-day/2010-12-01.csv")
df.printSchema()
df.createOrReplaceTempView("dfTable")

# %%
Excer

# %%
sc=spark.sparkContext
story=sc.textFile("data/NOTICE.txt")

# %%
words=story.flatMap(lambda x: x.split())
wordcount=words.countByValue()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 words=story.flatMap(lambda x: x.split())
#       2 wordcount=words.countByValue()
#
# NameError: name 'story' is not defined

# %%
wordcount=words.map(lambda x:( x,1)).reduceByKey(lambda x,y: x+y).map(lambda x: (x[1], x[0])).sortByKey(False)

# %%
print(wordcount)
# Out:
# PythonRDD[9] at RDD at PythonRDD.scala:53

# %%
wordcount.collect()
# Out:
# [(36, 'the'),
#  (22, 'to'),
#  (22, 'OR'),
#  (19, 'and'),
#  (18, 'THE'),
#  (17, 'of'),
#  (15, 'OF'),
#  (13, 'this'),
#  (12, 'in'),
#  (11, 'or'),
#  (11, 'IN'),
#  (9, 'software'),
#  (9, 'be'),
#  (8, 'any'),
#  (8, '----------------------------------------'),
#  (8, 'ANY'),
#  (7, 'source'),
#  (7, 'is'),
#  (7, 'must'),
#  (7, 'AND'),
#  (6, 'following'),
#  (6, 'FOR'),
#  (6, '-'),
#  (6, 'SOFTWARE'),
#  (5, 'Software,'),
#  (5, 'you'),
#  (5, 'a'),
#  (5, 'Software'),
#  (5, 'without'),
#  (5, 'not'),
#  (4, 'may'),
#  (4, 'documentation'),
#  (4, 'copyright'),
#  (4, 'above'),
#  (4, 'BUT'),
#  (4, 'COPYRIGHT'),
#  (4, 'OTHER'),
#  (4, 'use'),
#  (4, 'from'),
#  (4, 'including'),
#  (4, 'all'),
#  (4, 'copies'),
#  (4, 'NOT'),
#  (4, 'LIMITED'),
#  (4, 'LIABILITY,'),
#  (3, 'Permission'),
#  (3, 'subject'),
#  (3, 'The'),
#  (3, 'are'),
#  (3, 'IS'),
#  (3, 'PROVIDED'),
#  (3, '"AS'),
#  (3, 'EXPRESS'),
#  (3, 'NO'),
#  (3, 'SHALL'),
#  (3, 'BE'),
#  (3, 'LIABLE'),
#  (3, 'DAMAGES'),
#  (3, 'WHETHER'),
#  (3, 'CONTRACT,'),
#  (3, 'ARISING'),
#  (3, 'OUT'),
#  (3, 'USE'),
#  (3, 'software.'),
#  (3, 'conditions'),
#  (3, '*'),
#  (3, 'This'),
#  (3, 'Microsoft'),
#  (3, 'code'),
#  (3, 'for'),
#  (3, 'derivative'),
#  (3, 'works'),
#  (3, 'WARRANTIES'),
#  (3, 'A'),
#  (3, 'PARTICULAR'),
#  (3, 'EVENT'),
#  (3, 'HOLDERS'),
#  (3, 'TORT'),
#  (3, 'Copyright'),
#  (3, 'provided'),
#  (3, 'notice'),
#  (2, 'open'),
#  (2, 'other'),
#  (2, 'Boost'),
#  (2, 'free'),
#  (2, 'charge,'),
#  (2, 'person'),
#  (2, '(the'),
#  (2, 'use,'),
#  (2, 'distribute,'),
#  (2, 'do'),
#  (2, 'form'),
#  (2, 'IS",'),
#  (2, 'KIND,'),
#  (2, 'IMPLIED,'),
#  (2, 'INCLUDING'),
#  (2, 'TO'),
#  (2, 'OTHERWISE,'),
#  (2, 'FROM,'),
#  (2, 'CONNECTION'),
#  (2, 'SOFTWARE.'),
#  (2, 'Gailly'),
#  (2, 'Mark'),
#  (2, 'as'),
#  (2, 'distribution.'),
#  (2, 'and/or'),
#  (2, 'Florian'),
#  (2, 'binary'),
#  (2, 'notice,'),
#  (2, 'THIS'),
#  (2, 'IMPLIED'),
#  (2, 'TO,'),
#  (2, 'product'),
#  (2, 'name,'),
#  (2, 'hereby'),
#  (2, 'granted,'),
#  (2, 'obtaining'),
#  (2, 'copy'),
#  (2, 'by'),
#  (2, 'license'),
#  (2, 'permit'),
#  (2, 'whom'),
#  (2, 'so,'),
#  (2, 'included'),
#  (2, 'WITHOUT'),
#  (2, 'WARRANTY'),
#  (2, 'MERCHANTABILITY,'),
#  (2, 'FITNESS'),
#  (2, 'WITH'),
#  (2, 'DEALINGS'),
#  (2, '(C)'),
#  (2, 'Jean-loup'),
#  (2, 'Adler'),
#  (2, 'it'),
#  (2, 'that'),
#  (2, 'original'),
#  (2, 'All'),
#  (2, 'rights'),
#  (2, 'PURPOSE'),
#  (2, 'Reuter'),
#  (2, 'with'),
#  (2, 'Redistributions'),
#  (2, 'list'),
#  (2, 'CONTRIBUTORS'),
#  (1, 'Do'),
#  (1, 'Not'),
#  (1, 'material'),
#  (1, 'third'),
#  (1, 'certain'),
#  (1, 'at'),
#  (1, 'send'),
#  (1, 'check'),
#  (1, 'money'),
#  (1, 'version'),
#  (1, 'number,'),
#  (1, 'Source'),
#  (1, 'Code'),
#  (1, 'Compliance'),
#  (1, 'Corporation'),
#  (1, 'One'),
#  (1, 'USA'),
#  (1, 'Notwithstanding'),
#  (1, 'terms,'),
#  (1, 'reverse'),
#  (1, 'engineer'),
#  (1, 'extent'),
#  (1, 'debug'),
#  (1, 'GNU'),
#  (1, 'General'),
#  (1, 'Public'),
#  (1, 'License.'),
#  (1, 'https://www.boost.org/'),
#  (1, '1.0'),
#  (1, '17th,'),
#  (1, '2003'),
#  (1, 'accompanying'),
#  (1, 'covered'),
#  (1, '"Software")'),
#  (1, 'reproduce,'),
#  (1, 'transmit'),
#  (1, 'prepare'),
#  (1, 'third-parties'),
#  (1, 'furnished'),
#  (1, 'notices'),
#  (1, 'entire'),
#  (1, 'disclaimer,'),
#  (1, 'part,'),
#  (1, 'solely'),
#  (1, 'generated'),
#  (1, 'language'),
#  (1, 'PURPOSE,'),
#  (1, 'DISTRIBUTING'),
#  (1, 'zlib'),
#  (1, "'as-is',"),
#  (1, 'implied'),
#  (1, 'warranty.'),
#  (1, 'no'),
#  (1, 'event'),
#  (1, 'anyone'),
#  (1, 'purpose,'),
#  (1, 'commercial'),
#  (1, 'applications,'),
#  (1, 'redistribute'),
#  (1, '1.'),
#  (1, 'origin'),
#  (1, 'claim'),
#  (1, 'an'),
#  (1, 'would'),
#  (1, 'appreciated'),
#  (1, 'but'),
#  (1, 'required.'),
#  (1, 'versions'),
#  (1, 'such,'),
#  (1, '3.'),
#  (1, 'removed'),
#  (1, 'altered'),
#  (1, 'http://xmlsoft.org/'),
#  (1, '1998-2012'),
#  (1, 'Rights'),
#  (1, 'Reserved.'),
#  (1, 'files'),
#  (1, 'deal'),
#  (1, 'restriction,'),
#  (1, 'copy,'),
#  (1, 'merge,'),
#  (1, 'publish,'),
#  (1, 'sublicense,'),
#  (1, 'fur-'),
#  (1, 'nished'),
#  (1, 'substantial'),
#  (1, 'NONINFRINGEMENT.'),
#  (1, 'CLAIM,'),
#  (1, '2010/2011,'),
#  (1, 'Redistribution'),
#  (1, 'permitted'),
#  (1, 'reproduce'),
#  (1, 'Neither'),
#  (1, 'name'),
#  (1, 'nor'),
#  (1, 'names'),
#  (1, 'contributors'),
#  (1, 'used'),
#  (1, 'promote'),
#  (1, 'derived'),
#  (1, 'specific'),
#  (1, 'permission.'),
#  (1, 'IS"'),
#  (1, 'WARRANTIES,'),
#  (1, 'INCLUDING,'),
#  (1, 'MERCHANTABILITY'),
#  (1, 'ARE'),
#  (1, 'DISCLAIMED.'),
#  (1, 'SPECIAL,'),
#  (1, 'PROCUREMENT'),
#  (1, 'SUBSTITUTE'),
#  (1, 'SERVICES;'),
#  (1, 'LOSS'),
#  (1, 'PROFITS;'),
#  (1, 'CAUSED'),
#  (1, 'THEORY'),
#  (1, 'STRICT'),
#  (1, '(INCLUDING'),
#  (1, 'NEGLIGENCE'),
#  (1, 'DAMAGE.'),
#  (1, 'NOTICES'),
#  (1, 'INFORMATION'),
#  (1, 'Translate'),
#  (1, 'Localize'),
#  (1, 'incorporates'),
#  (1, 'parties.'),
#  (1, 'makes'),
#  (1, 'available'),
#  (1, 'https://3rdpartysource.microsoft.com,'),
#  (1, 'order'),
#  (1, 'US'),
#  (1, '$5.00,'),
#  (1, 'component'),
#  (1, 'to:'),
#  (1, 'Team'),
#  (1, 'Way'),
#  (1, 'Redmond,'),
#  (1, 'WA'),
#  (1, '98052'),
#  (1, 'required'),
#  (1, 'changes'),
#  (1, 'libraries'),
#  (1, 'licensed'),
#  (1, 'under'),
#  (1, 'Lesser'),
#  (1, 'License'),
#  (1, 'Version'),
#  (1, 'August'),
#  (1, 'organization'),
#  (1, 'display,'),
#  (1, 'execute,'),
#  (1, 'following:'),
#  (1, 'statement,'),
#  (1, 'grant,'),
#  (1, 'restriction'),
#  (1, 'whole'),
#  (1, 'unless'),
#  (1, 'such'),
#  (1, 'machine-executable'),
#  (1, 'object'),
#  (1, 'processor.'),
#  (1, 'TITLE'),
#  (1, 'NON-INFRINGEMENT.'),
#  (1, 'ANYONE'),
#  (1, 'http://www.zlib.org/'),
#  (1, '1995-2017'),
#  (1, 'express'),
#  (1, 'In'),
#  (1, 'will'),
#  (1, 'authors'),
#  (1, 'held'),
#  (1, 'liable'),
#  (1, 'damages'),
#  (1, 'arising'),
#  (1, 'granted'),
#  (1, 'alter'),
#  (1, 'freely,'),
#  (1, 'restrictions:'),
#  (1, 'misrepresented;'),
#  (1, 'wrote'),
#  (1, 'If'),
#  (1, 'product,'),
#  (1, 'acknowledgment'),
#  (1, '2.'),
#  (1, 'Altered'),
#  (1, 'plainly'),
#  (1, 'marked'),
#  (1, 'misrepresented'),
#  (1, 'being'),
#  (1, 'jloup@gzip.org'),
#  (1, 'madler@alumni.caltech.edu'),
#  (1, 'Libxml2'),
#  (1, 'Daniel'),
#  (1, 'Veillard.'),
#  (1, 'associated'),
#  (1, '"Software"),'),
#  (1, 'limitation'),
#  (1, 'modify,'),
#  (1, 'sell'),
#  (1, 'persons'),
#  (1, 'conditions:'),
#  (1, 'permission'),
#  (1, 'shall'),
#  (1, 'portions'),
#  (1, 'Software.'),
#  (1, 'FIT-'),
#  (1, 'NESS'),
#  (1, 'AUTHORS'),
#  (1, 'AN'),
#  (1, 'ACTION'),
#  (1, 'libopc'),
#  (1, 'https://github.com/freuter/libopc'),
#  (1, '(c)'),
#  (1, 'reserved.'),
#  (1, 'forms,'),
#  (1, 'modification,'),
#  (1, 'met:'),
#  (1, 'retain'),
#  (1, 'disclaimer.'),
#  (1, 'disclaimer'),
#  (1, 'materials'),
#  (1, 'its'),
#  (1, 'endorse'),
#  (1, 'products'),
#  (1, 'prior'),
#  (1, 'written'),
#  (1, 'BY'),
#  (1, 'OWNER'),
#  (1, 'DIRECT,'),
#  (1, 'INDIRECT,'),
#  (1, 'INCIDENTAL,'),
#  (1, 'EXEMPLARY,'),
#  (1, 'CONSEQUENTIAL'),
#  (1, '(INCLUDING,'),
#  (1, 'GOODS'),
#  (1, 'USE,'),
#  (1, 'DATA,'),
#  (1, 'BUSINESS'),
#  (1, 'INTERRUPTION)'),
#  (1, 'HOWEVER'),
#  (1, 'ON'),
#  (1, 'OTHERWISE)'),
#  (1, 'WAY'),
#  (1, 'SOFTWARE,'),
#  (1, 'EVEN'),
#  (1, 'IF'),
#  (1, 'ADVISED'),
#  (1, 'POSSIBILITY'),
#  (1, 'SUCH')]
